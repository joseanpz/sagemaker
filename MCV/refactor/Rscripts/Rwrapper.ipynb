# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       32941452 kB
# MemFree:        31078344 kB
# MemAvailable:   31945392 kB
# Buffers:          144948 kB
# Cached:          1042444 kB
# SwapCached:            0 kB
# Active:           981140 kB
# Inactive:         681628 kB
# Active(anon):     475376 kB
# Inactive(anon):       60 kB
# Active(file):     505764 kB
# Inactive(file):   681568 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               180 kB
# Writeback:             0 kB
# AnonPages:        475540 kB
# Mapped:           145576 kB
# Shmem:                72 kB
# Slab:             111128 kB
# SReclaimable:      86216 kB
# SUnreclaim:        24912 kB
# KernelStack:        4240 kB
# PageTables:         5756 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:    16470724 kB
# Committed_AS:    1740772 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
# !sudo yum install libxml2-devel R -y
# Out:
# Loaded plugins: dkms-build-requires, priorities, update-motd, upgrade-helper
# amzn-main                                                | 2.1 kB     00:00
# amzn-updates                                             | 2.5 kB     00:00
# libnvidia-container/x86_64/signature                     |  455 B     00:00
# Retrieving key from https://nvidia.github.io/libnvidia-container/gpgkey
# libnvidia-container/x86_64/signature                     | 2.0 kB     00:00 !!!
# https://nvidia.github.io/libnvidia-container/amzn1/x86_64/repodata/repomd.xml: [Errno -1] repomd.xml signature could not be verified for libnvidia-container
# Trying other mirror.
# nvidia-container-runtime/x86_64/signature                |  455 B     00:00
# Retrieving key from https://nvidia.github.io/nvidia-container-runtime/gpgkey
# nvidia-container-runtime/x86_64/signature                | 2.0 kB     00:00 !!!
# ...

# %%
# !sudo R -e 'install.packages(c("BVSNLP", "BH", "xml2", "BayesVarSel"), repos=c("https://cloud.r-project.org"))' # install to default location.
#!sudo R -e 'install.packages(c("xml2"), repos=c("https://cloud.r-project.org"))'
#!sudo R -e 'install.packages(c("BVSNLP", "aws.s3"), lib="/usr/local/lib/R/site-library")' # install to location that requires root.
# Out:
# R version 3.4.1 (2017-06-30) -- "Single Candle"
# Copyright (C) 2017 The R Foundation for Statistical Computing
# Platform: x86_64-redhat-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > install.packages(c("BVSNLP", "BH", "xml2", "BayesVarSel"), repos=c("https://cloud.r-project.org"))
# Installing packages into ‘/usr/lib64/R/library’
# (as ‘lib’ is unspecified)
# ...

# %%
# !sudo R -e 'install.packages("aws.s3", repos = c("cloudyr" = "http://cloudyr.github.io/drat"), INSTALL_opts = "--no-multiarch")'
# Out:
# R version 3.4.1 (2017-06-30) -- "Single Candle"
# Copyright (C) 2017 The R Foundation for Statistical Computing
# Platform: x86_64-redhat-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > install.packages("aws.s3", repos = c("cloudyr" = "http://cloudyr.github.io/drat"), INSTALL_opts = "--no-multiarch")
# Installing package into ‘/usr/lib64/R/library’
# (as ‘lib’ is unspecified)
# trying URL 'http://cloudyr.github.io/drat/src/contrib/aws.s3_0.3.20.tar.gz'
# ...

# %%
# !ls -la /tmp && cat /tmp/bvsnlp_feat_sel.csv
# Out:
# total 10360
# drwxrwxrwx  7 root       root         266240 Oct 31 20:10 .
# dr-xr-xr-x 26 root       root           4096 Oct 31 15:49 ..
# -rw-rw-r--  1 ec2-user   ec2-user        138 Oct 31 20:10 bvsnlp_feat_sel.csv
# drwxr-xr-x  2 role-agent role-agent     4096 Oct 31 15:49 hsperfdata_role-agent
# drwxr-xr-x  2 root       root           4096 Oct 31 16:09 hsperfdata_root
# drwxrwxrwt  2 root       root           4096 Oct 31 15:49 .ICE-unix
# drwxr-xr-x  3 role-agent role-agent     4096 Oct 31 15:50 jetty-0.0.0.0-9081-role-proxy-agent.war-_-any-3693310923957976807.dir
# drwx------  2 ec2-user   ec2-user       4096 Oct 31 19:55 RtmpmPndwp
# -rw-rw-r--  1 ec2-user   ec2-user   10308588 Oct 31 17:20 strategy2_prp.csv
# "Feature","Coeficient"
# "INTERCEPT",-3.45876302009801
# "AVG_R_BAL_BY_CRED_LIM_12M",1.33611007790311
# "NUM_VENCIDO1MAS_03M",0.626488393021573

# %%
# !Rscript bayes_var_sel_nlp.R
# Out:
# Bayesian Variable Selection using Non-Local priors for survival and logistic regression data.
# Loading Version 1.1.5
# There were 30 warnings (use warnings() to see them)
# [1] "AVG_R_BAL_BY_CRED_LIM_12M" "NUM_VENCIDO1MAS_03M"

# %%
# !Rscript bayes_var_sel_hyperselect.R
# Out:
# Bayesian Variable Selection using Non-Local priors for survival and logistic regression data.
# Loading Version 1.1.5
# Warning messages:
# 1: In is.na(f.lower) :
#   is.na() applied to non-(list or vector) of type 'NULL'
# 2: In is.na(f.lower) :
#   is.na() applied to non-(list or vector) of type 'NULL'
# 3: In is.na(f.lower) :
#   is.na() applied to non-(list or vector) of type 'NULL'
# $tau
# [1] 0.25
